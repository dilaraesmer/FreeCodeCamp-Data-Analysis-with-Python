# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraesmer/FreeCodeCamp/blob/main/reading_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Reading CSV and TXT files

# %%
import pandas as pd

# %%
with open('btc-market-price.csv', 'r') as fp:
  print(fp)
# Out:
# <_io.TextIOWrapper name='btc-market-price.csv' mode='r' encoding='UTF-8'>

# %%
with open('btc-market-price.csv', 'r') as fp:
  for index, line in enumerate(fp.readlines()):
  # read just the first 10 lines
    if (index < 10):
      print(index, line)
# Out:
# 0 2017-04-02 00:00:00,1099.169125
#
# 1 2017-04-03 00:00:00,1141.813
#
# 2 2017-04-04 00:00:00,1141.6003625
#
# 3 2017-04-05 00:00:00,1133.0793142857142
#
# 4 2017-04-06 00:00:00,1196.3079375
#
# 5 2017-04-07 00:00:00,1190.45425
#
# 6 2017-04-08 00:00:00,1181.1498375
#
# 7 2017-04-09 00:00:00,1208.8005
#
# 8 2017-04-10 00:00:00,1207.744875
#
# 9 2017-04-11 00:00:00,1226.6170375

# %%
pd.read_csv?

# %%
csv_url = "https://raw.githubusercontent.com/datasets/gdp/master/data/gdp.csv"
pd.read_csv(csv_url).head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
df = pd.read_csv('btc-market-price.csv')
df.head()
# Out:
#    2017-04-02 00:00:00  1099.169125
# 0  2017-04-03 00:00:00  1141.813000
# 1  2017-04-04 00:00:00  1141.600363
# 2  2017-04-05 00:00:00  1133.079314
# 3  2017-04-06 00:00:00  1196.307937
# 4  2017-04-07 00:00:00  1190.454250

# %%
df = pd.read_csv('btc-market-price.csv', header=None)
df.head()
# Out:
#                      0            1
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %% [markdown]
# Missing values with na_values parameter

# %%
df = pd.read_csv('btc-market-price.csv', header=None, 
                 na_values=['','?','-'])

# %%
df.head()
# Out:
#                      0            1
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %% [markdown]
# Column names using names parameter

# %%
df = pd.read_csv('btc-market-price.csv', header=None, 
                 na_values=['','?','-'],
                 names=['Timestamp', 'Price'])

# %%
df.head()
# Out:
#                      0            1
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  365 non-null    object
#  1   Price      365 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 5.8+ KB

# %% [markdown]
# Column types using dtype parameter

# %%
df = pd.read_csv('btc-market-price.csv', header=None, 
                 na_values=['','?','-'],
                 names=['Timestamp', 'Price'],
                 dtype={'Price' : 'float'})

# %%
df.head()
# Out:
#              Timestamp        Price
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
df.dtypes
# Out:
# Timestamp     object
# Price        float64
# dtype: object

# %%
pd.to_datetime(df['Timestamp']).head()
# Out:
# 0   2017-04-02
# 1   2017-04-03
# 2   2017-04-04
# 3   2017-04-05
# 4   2017-04-06
# Name: Timestamp, dtype: datetime64[ns]

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df.head()
# Out:
#    Timestamp        Price
# 0 2017-04-02  1099.169125
# 1 2017-04-03  1141.813000
# 2 2017-04-04  1141.600363
# 3 2017-04-05  1133.079314
# 4 2017-04-06  1196.307937

# %%
df.dtypes
# Out:
# Timestamp    datetime64[ns]
# Price               float64
# dtype: object

# %% [markdown]
# Date parser using parse_dates parameter

# %%
df = pd.read_csv('btc-market-price.csv', header=None, 
                 na_values=['','?','-'],
                 names=['Timestamp', 'Price'],
                 dtype={'Price' : 'float'},
                 parse_dates=[0])

# %%
df.head()
# Out:
#    Timestamp        Price
# 0 2017-04-02  1099.169125
# 1 2017-04-03  1141.813000
# 2 2017-04-04  1141.600363
# 3 2017-04-05  1133.079314
# 4 2017-04-06  1196.307937

# %%
df.dtypes
# Out:
# Timestamp    datetime64[ns]
# Price               float64
# dtype: object

# %%
courses_df = pd.read_csv('coursera_data.csv')

# %%
courses_df
# Out:
#      course_id                                       course_title  \
# 0          134  (ISC)² Systems Security Certified Practitioner...
# 1          743  A Crash Course in Causality:  Inferring Causal...
# 2          874                     A Crash Course in Data Science
# 3          413                            A Law Student's Toolkit
# 4          635                A Life of Happiness and Fulfillment
# ..         ...                                                ...
# 869        213               Write Professional Emails in English
# 870        684                             Write Your First Novel
# 871         69                            Writing in the Sciences
# 872        359  e-Learning Ecologies: Innovative Approaches to...
# 873        779                     iOS App Development with Swift
#
#                             course_organization course_Certificate_type  \
# 0                                        (ISC)²          SPECIALIZATION
# ...

# %%
courses_df[['course_title', 'course_rating']].dtypes
# Out:
# course_title      object
# course_rating    float64
# dtype: object

# %%
courses_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 874 entries, 0 to 873
# Data columns (total 7 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   course_id                              874 non-null    int64
#  1   course_title                           874 non-null    object
#  2   course_organization                    874 non-null    object
#  3   course_Certificate_type                874 non-null    object
#  4   course_rating                          874 non-null    float64
#  5   course_difficulty                      874 non-null    object
#  6   course_students_enrolled_in_thousands  874 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 47.9+ KB

# %%
with open("FEVdata.txt") as file:
    print(file.read())
# Out:
#     1   301    9 1.708 57.0    2    2
#     2   451    8 1.724 67.5    2    2
#     3   501    7 1.720 54.5    2    2
#     4   642    9 1.558 53.0    1    2
#     5   901    9 1.895 57.0    1    2
#     6  1701    8 2.336 61.0    2    2
#     7  1752    6 1.919 58.0    2    2
#     8  1753    6 1.415 56.0    2    2
#     9  1901    8 1.987 58.5    2    2
#    10  1951    9 1.942 60.0    2    2
#    11  1952    6 1.602 53.0    2    2
#    12  2001    8 1.735 54.0    1    2
#    13  2101    8 2.193 58.5    2    2
#    14  2401    8 2.118 60.5    1    2
#    15  3102    8 2.258 58.0    1    2
#    16  3142    7 1.932 53.0    1    2
#    17  3541    5 1.472 50.0    1    2
#    18  3551    6 1.878 53.0    2    2
#    19  4201    9 2.352 59.0    1    2
#    20  4301    9 2.604 61.5    1    2
#    21  4351    5 1.400 49.0    2    2
#    22  5151    5 1.256 52.5    2    2
#    23  5152    4 0.839 48.0    2    2
#    24  5201    7 2.578 62.5    1    2
#    25  5601    9 2.988 65.0    2    2
# ...

# %%
with open("FEVdata.txt") as file:
    print(file.readline())
# Out:
#     1   301    9 1.708 57.0    2    2

# %%
with open("FEVdata.txt") as file:
    print(file.readlines())
# Out:
# ['    1   301    9 1.708 57.0    2    2\n', '    2   451    8 1.724 67.5    2    2\n', '    3   501    7 1.720 54.5    2    2\n', '    4   642    9 1.558 53.0    1    2\n', '    5   901    9 1.895 57.0    1    2\n', '    6  1701    8 2.336 61.0    2    2\n', '    7  1752    6 1.919 58.0    2    2\n', '    8  1753    6 1.415 56.0    2    2\n', '    9  1901    8 1.987 58.5    2    2\n', '   10  1951    9 1.942 60.0    2    2\n', '   11  1952    6 1.602 53.0    2    2\n', '   12  2001    8 1.735 54.0    1    2\n', '   13  2101    8 2.193 58.5    2    2\n', '   14  2401    8 2.118 60.5    1    2\n', '   15  3102    8 2.258 58.0    1    2\n', '   16  3142    7 1.932 53.0    1    2\n', '   17  3541    5 1.472 50.0    1    2\n', '   18  3551    6 1.878 53.0    2    2\n', '   19  4201    9 2.352 59.0    1    2\n', '   20  4301    9 2.604 61.5    1    2\n', '   21  4351    5 1.400 49.0    2    2\n', '   22  5151    5 1.256 52.5    2    2\n', '   23  5152    4 0.839 48.0    2    2\n', '   24  
# ...

# %%
with open("FEVdata.txt") as file:
    for item in file:
        print(item)
# Out:
#     1   301    9 1.708 57.0    2    2
#
#     2   451    8 1.724 67.5    2    2
#
#     3   501    7 1.720 54.5    2    2
#
#     4   642    9 1.558 53.0    1    2
#
#     5   901    9 1.895 57.0    1    2
#
#     6  1701    8 2.336 61.0    2    2
#
#     7  1752    6 1.919 58.0    2    2
#
#     8  1753    6 1.415 56.0    2    2
#
#     9  1901    8 1.987 58.5    2    2
#
#    10  1951    9 1.942 60.0    2    2
#
#    11  1952    6 1.602 53.0    2    2
#
#    12  2001    8 1.735 54.0    1    2
#
#    13  2101    8 2.193 58.5    2    2
#
#    14  2401    8 2.118 60.5    1    2
#
#    15  3102    8 2.258 58.0    1    2
#
#    16  3142    7 1.932 53.0    1    2
#
#    17  3541    5 1.472 50.0    1    2
#
#    18  3551    6 1.878 53.0    2    2
#
#    19  4201    9 2.352 59.0    1    2
#
#    20  4301    9 2.604 61.5    1    2
#
#    21  4351    5 1.400 49.0    2    2
#
#    22  5151    5 1.256 52.5    2    2
#
#    23  5152    4 0.839 48.0    2    2
#
# ...
