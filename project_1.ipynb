# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraesmer/FreeCodeCamp/blob/main/project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# libraries required for data analysis

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('adult.data.csv')

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.tail()
# Out:
#        age workclass  fnlwgt     education  education-num      marital-status  \
# 19407   23   Private  222835     Bachelors             13       Never-married
# 19408   46   Private  251786       1st-4th              2           Separated
# 19409   20   Private  164219       HS-grad              9       Never-married
# 19410   33   Private  251120     Bachelors             13  Married-civ-spouse
# 19411   30   Private  236993  Some-college             10       Never-married
#
#               occupation   relationship   race     sex  capital-gain  \
# 19407      Other-service      Own-child  White  Female             0
# 19408      Other-service  Not-in-family  White  Female             0
# 19409  Handlers-cleaners      Own-child  White    Male             0
# 19410              Sales        Husband  White    Male          7688
# 19411       Adm-clerical      Unmarried  White  Female             0
#
#        capital-loss  hours-per-week native-country salary
# ...

# %%
df.shape
# Out:
# (19412, 15)

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
df.value_counts()
# Out:
# age  workclass         fnlwgt  education     education-num  marital-status      occupation       relationship   race                sex     capital-gain  capital-loss  hours-per-week  native-country  salary
# 21   Private           243368  Preschool     1              Never-married       Farming-fishing  Not-in-family  White               Male    0             0             50              Mexico          <=50K     2
# 25   Private           308144  Bachelors     13             Never-married       Craft-repair     Not-in-family  White               Male    0             0             40              Mexico          <=50K     2
# 19   Private           97261   HS-grad       9              Never-married       Farming-fishing  Not-in-family  White               Male    0             0             40              United-States   <=50K     2
# ...

# %%
df.dropna(axis=0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19412 entries, 0 to 19411
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             19412 non-null  int64
#  1   workclass       19412 non-null  object
#  2   fnlwgt          19412 non-null  int64
#  3   education       19412 non-null  object
#  4   education-num   19412 non-null  int64
#  5   marital-status  19412 non-null  object
#  6   occupation      19412 non-null  object
#  7   relationship    19412 non-null  object
#  8   race            19412 non-null  object
#  9   sex             19412 non-null  object
#  10  capital-gain    19412 non-null  int64
#  11  capital-loss    19412 non-null  int64
#  12  hours-per-week  19412 non-null  int64
#  13  native-country  19412 non-null  object
#  14  salary          19412 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 2.4+ MB

# %%
df.set_index('race')
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# race
# White   39         State-gov   77516     Bachelors             13
# White   50  Self-emp-not-inc   83311     Bachelors             13
# White   38           Private  215646       HS-grad              9
# Black   53           Private  234721          11th              7
# Black   28           Private  338409     Bachelors             13
# ...    ...               ...     ...           ...            ...
# White   23           Private  222835     Bachelors             13
# White   46           Private  251786       1st-4th              2
# White   20           Private  164219       HS-grad              9
# White   33           Private  251120     Bachelors             13
# White   30           Private  236993  Some-college             10
#
#            marital-status         occupation   relationship     sex  \
# race
# White       Never-married       Adm-clerical  Not-in-family    Male
# ...

# %%
df.mean()
# Out:
# <ipython-input-46-c61f0c8f89b5>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# age                   38.596332
# fnlwgt            189868.662013
# education-num         10.085978
# capital-gain        1070.674171
# capital-loss          87.590614
# hours-per-week        40.391201
# dtype: float64

# %%
df[["sex", "age"]].groupby("sex").mean()
# Out:
#               age
# sex
# Female  37.029860
# Male    39.372208

# %%
df['education'].value_counts()
# Out:
# HS-grad         6347
# Some-college    4341
# Bachelors       3232
# Masters         1017
# Assoc-voc        813
# 11th             694
# Assoc-acdm       616
# 10th             554
# 7th-8th          377
# Prof-school      327
# 9th              301
# Doctorate        245
# 12th             230
# 5th-6th          196
# 1st-4th           97
# Preschool         25
# Name: education, dtype: int64

# %%
df['education'].values
# Out:
# array(['Bachelors', 'Bachelors', 'HS-grad', ..., 'HS-grad', 'Bachelors',
#        'Some-college'], dtype=object)

# %%
df[df['education'] == 'Bachelors']
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 4       28           Private  338409  Bachelors             13
# 9       42           Private  159449  Bachelors             13
# 11      30         State-gov  141297  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 19374   22           Private  201268  Bachelors             13
# 19395   30           Private  183284  Bachelors             13
# 19398   34           Private  118551  Bachelors             13
# 19407   23           Private  222835  Bachelors             13
# 19410   33           Private  251120  Bachelors             13
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
df[df['education'] == 'Bachelors'].count()
# Out:
# age               3232
# workclass         3232
# fnlwgt            3232
# education         3232
# education-num     3232
# marital-status    3232
# occupation        3232
# relationship      3232
# race              3232
# sex               3232
# capital-gain      3232
# capital-loss      3232
# hours-per-week    3232
# native-country    3232
# salary            3232
# dtype: int64

# %%
df['education'].count()
# Out:
# 19412

# %%
3232/19412 * 100
# Out:
# 16.649495157634455

# %%
df.sum()
# Out:
# age                                                          749232
# workclass         State-govSelf-emp-not-incPrivatePrivatePrivate...
# fnlwgt                                                   3685730467
# education         BachelorsBachelorsHS-grad11thBachelorsMasters9...
# education-num                                                195789
# marital-status    Never-marriedMarried-civ-spouseDivorcedMarried...
# occupation        Adm-clericalExec-managerialHandlers-cleanersHa...
# relationship      Not-in-familyHusbandNot-in-familyHusbandWifeWi...
# race              WhiteWhiteWhiteBlackBlackWhiteBlackWhiteWhiteW...
# sex               MaleMaleMaleMaleFemaleFemaleFemaleMaleFemaleMa...
# capital-gain                                               20783927
# capital-loss                                                1700309
# hours-per-week                                               784074
# native-country    United-StatesUnited-StatesUnited-StatesUnited-...
# ...

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             19412.0      38.596332      13.655907     17.0      28.0
# fnlwgt          19412.0  189868.662013  105613.893133  12285.0  118551.0
# education-num   19412.0      10.085978       2.555847      1.0       9.0
# capital-gain    19412.0    1070.674171    7384.294747      0.0       0.0
# capital-loss    19412.0      87.590614     401.852310      0.0       0.0
# hours-per-week  19412.0      40.391201      12.259320      1.0      40.0
#
#                      50%        75%        max
# age                 37.0      48.00       90.0
# fnlwgt          178255.0  237465.75  1484705.0
# education-num       10.0      12.00       16.0
# capital-gain         0.0       0.00    99999.0
# capital-loss         0.0       0.00     4356.0
# hours-per-week      40.0      45.00       99.0

# %%
df.isnull().values.any()
# there is no null values
# Out:
# False

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)
