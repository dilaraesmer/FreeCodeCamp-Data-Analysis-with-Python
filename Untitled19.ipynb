# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraesmer/FreeCodeCamp/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cars.csv', sep =';')

# %%
df
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2            Buick Skylark 320    15.0         8        350.0      165.0
# 3           Plymouth Satellite    18.0         8        318.0      150.0
# 4                AMC Rebel SST    16.0         8        304.0      150.0
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL    27.0         4        140.0      86.00
# 403          Volkswagen Pickup    44.0         4        97.00      52.00
# 404              Dodge Rampage    32.0         4        135.0      84.00
# 405                Ford Ranger    28.0         4        120.0      79.00
# 406                 Chevy S-10    31.0         4        119.0      82.00
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# 1     3504.         12.0    70      US
# 2     3693.         11.5    70      US
# 3     3436.         11.0    70      US
# 4     3433.         12.0    70      US
# ..      ...          ...   ...     ...
# 402   2790.         15.6    82      US
# 403   2130.         24.6    82  Europe
# 404   2295.         11.6    82      US
# 405   2625.         18.6    82      US
# 406   2720.         19.4    82      US
#
# [407 rows x 9 columns]

# %%
df.head()
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0      165.0
# 3         Plymouth Satellite    18.0         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8        304.0      150.0
#
#    Weight Acceleration Model Origin
# 0  DOUBLE       DOUBLE   INT    CAT
# 1   3504.         12.0    70     US
# 2   3693.         11.5    70     US
# 3   3436.         11.0    70     US
# 4   3433.         12.0    70     US

# %%
df.loc[0]
# Out:
# Car             STRING
# MPG             DOUBLE
# Cylinders          INT
# Displacement    DOUBLE
# Horsepower      DOUBLE
# Weight          DOUBLE
# Acceleration    DOUBLE
# Model              INT
# Origin             CAT
# Name: 0, dtype: object

# %%
df.drop([0], inplace=True)

# %%
df
# Out:
#                            Car   MPG Cylinders Displacement Horsepower Weight  \
# 1    Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# 2            Buick Skylark 320  15.0         8        350.0      165.0  3693.
# 3           Plymouth Satellite  18.0         8        318.0      150.0  3436.
# 4                AMC Rebel SST  16.0         8        304.0      150.0  3433.
# 5                  Ford Torino  17.0         8        302.0      140.0  3449.
# ..                         ...   ...       ...          ...        ...    ...
# 402            Ford Mustang GL  27.0         4        140.0      86.00  2790.
# 403          Volkswagen Pickup  44.0         4        97.00      52.00  2130.
# 404              Dodge Rampage  32.0         4        135.0      84.00  2295.
# 405                Ford Ranger  28.0         4        120.0      79.00  2625.
# 406                 Chevy S-10  31.0         4        119.0      82.00  2720.
#
#     Acceleration Model  Origin
# 1           12.0    70      US
# 2           11.5    70      US
# 3           11.0    70      US
# 4           12.0    70      US
# 5           10.5    70      US
# ..           ...   ...     ...
# 402         15.6    82      US
# 403         24.6    82  Europe
# 404         11.6    82      US
# 405         18.6    82      US
# 406         19.4    82      US
#
# [406 rows x 9 columns]

# %%
df.loc[400]
# Out:
# Car             Dodge Charger 2.2
# MPG                          36.0
# Cylinders                       4
# Displacement                135.0
# Horsepower                  84.00
# Weight                      2370.
# Acceleration                 13.0
# Model                          82
# Origin                         US
# Name: 400, dtype: object

# %%
df.iloc[[0, 1, -1]]
# Out:
#                            Car   MPG Cylinders Displacement Horsepower Weight  \
# 1    Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# 2            Buick Skylark 320  15.0         8        350.0      165.0  3693.
# 406                 Chevy S-10  31.0         4        119.0      82.00  2720.
#
#     Acceleration Model Origin
# 1           12.0    70     US
# 2           11.5    70     US
# 406         19.4    82     US

# %%
df.iloc[0:3, [0,3]]
# Out:
#                          Car Displacement
# 1  Chevrolet Chevelle Malibu        307.0
# 2          Buick Skylark 320        350.0
# 3         Plymouth Satellite        318.0

# %%
df.iloc[0:3, 1:5]
# Out:
#     MPG Cylinders Displacement Horsepower
# 1  18.0         8        307.0      130.0
# 2  15.0         8        350.0      165.0
# 3  18.0         8        318.0      150.0

# %%
df
# Out:
#                            Car   MPG Cylinders Displacement Horsepower Weight  \
# 1    Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# 2            Buick Skylark 320  15.0         8        350.0      165.0  3693.
# 3           Plymouth Satellite  18.0         8        318.0      150.0  3436.
# 4                AMC Rebel SST  16.0         8        304.0      150.0  3433.
# 5                  Ford Torino  17.0         8        302.0      140.0  3449.
# ..                         ...   ...       ...          ...        ...    ...
# 402            Ford Mustang GL  27.0         4        140.0      86.00  2790.
# 403          Volkswagen Pickup  44.0         4        97.00      52.00  2130.
# 404              Dodge Rampage  32.0         4        135.0      84.00  2295.
# 405                Ford Ranger  28.0         4        120.0      79.00  2625.
# 406                 Chevy S-10  31.0         4        119.0      82.00  2720.
#
#     Acceleration Model  Origin
# 1           12.0    70      US
# 2           11.5    70      US
# 3           11.0    70      US
# 4           12.0    70      US
# 5           10.5    70      US
# ..           ...   ...     ...
# 402         15.6    82      US
# 403         24.6    82  Europe
# 404         11.6    82      US
# 405         18.6    82      US
# 406         19.4    82      US
#
# [406 rows x 9 columns]

# %%
df.set_index('Car')
# Out:
#                             MPG Cylinders Displacement Horsepower Weight  \
# Car
# Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# Buick Skylark 320          15.0         8        350.0      165.0  3693.
# Plymouth Satellite         18.0         8        318.0      150.0  3436.
# AMC Rebel SST              16.0         8        304.0      150.0  3433.
# Ford Torino                17.0         8        302.0      140.0  3449.
# ...                         ...       ...          ...        ...    ...
# Ford Mustang GL            27.0         4        140.0      86.00  2790.
# Volkswagen Pickup          44.0         4        97.00      52.00  2130.
# Dodge Rampage              32.0         4        135.0      84.00  2295.
# Ford Ranger                28.0         4        120.0      79.00  2625.
# Chevy S-10                 31.0         4        119.0      82.00  2720.
#
#                           Acceleration Model  Origin
# Car
# Chevrolet Chevelle Malibu         12.0    70      US
# Buick Skylark 320                 11.5    70      US
# Plymouth Satellite                11.0    70      US
# AMC Rebel SST                     12.0    70      US
# Ford Torino                       10.5    70      US
# ...                                ...   ...     ...
# Ford Mustang GL                   15.6    82      US
# Volkswagen Pickup                 24.6    82  Europe
# Dodge Rampage                     11.6    82      US
# Ford Ranger                       18.6    82      US
# Chevy S-10                        19.4    82      US
#
# [406 rows x 8 columns]

# %%
type('MPG')
# Out:
# str

# %%
df['MPG'] = df['MPG'].astype(int)

# %%
print(df.dtypes)
# Out:
# Car             object
# MPG              int64
# Cylinders       object
# Displacement    object
# Horsepower      object
# Weight          object
# Acceleration    object
# Model           object
# Origin          object
# dtype: object

# %%
df['MPG'] = pd.to_numeric(df['MPG'])

# %%
print(df.dtypes)
# Out:
# Car             object
# MPG              int64
# Cylinders       object
# Displacement    object
# Horsepower      object
# Weight          object
# Acceleration    object
# Model           object
# Origin          object
# dtype: object

# %%
df['MPG'] > 30
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 402    False
# 403     True
# 404     True
# 405    False
# 406     True
# Name: MPG, Length: 406, dtype: bool

# %%
print(type('MPG'))
# Out:
# <class 'str'>

# %%
df.loc[df['MPG'] > 30]
# Out:
#                      Car  MPG Cylinders Displacement Horsepower Weight  \
# 61   Toyota Corolla 1200   31         4        71.00      65.00  1773.
# 62           Datsun 1200   35         4        72.00      69.00  1613.
# 137          Datsun B210   31         4        79.00      67.00  1950.
# 139  Toyota Corolla 1200   32         4        71.00      65.00  1836.
# 152       Toyota Corolla   31         4        76.00      52.00  1649.
# ..                   ...  ...       ...          ...        ...    ...
# 399     Toyota Celica GT   32         4        144.0      96.00  2665.
# 400    Dodge Charger 2.2   36         4        135.0      84.00  2370.
# 403    Volkswagen Pickup   44         4        97.00      52.00  2130.
# 404        Dodge Rampage   32         4        135.0      84.00  2295.
# 406           Chevy S-10   31         4        119.0      82.00  2720.
#
#     Acceleration Model  Origin
# 61          19.0    71   Japan
# 62          18.0    71   Japan
# 137         19.0    74   Japan
# 139         21.0    74   Japan
# 152         16.5    74   Japan
# ..           ...   ...     ...
# 399         13.9    82   Japan
# 400         13.0    82      US
# 403         24.6    82  Europe
# 404         11.6    82      US
# 406         19.4    82      US
#
# [81 rows x 9 columns]
