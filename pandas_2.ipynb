# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraesmer/FreeCodeCamp/blob/main/pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cars.csv', sep =';')

# %%
df
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2            Buick Skylark 320    15.0         8        350.0      165.0
# 3           Plymouth Satellite    18.0         8        318.0      150.0
# 4                AMC Rebel SST    16.0         8        304.0      150.0
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL    27.0         4        140.0      86.00
# 403          Volkswagen Pickup    44.0         4        97.00      52.00
# 404              Dodge Rampage    32.0         4        135.0      84.00
# 405                Ford Ranger    28.0         4        120.0      79.00
# 406                 Chevy S-10    31.0         4        119.0      82.00
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %%
df.head()
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0      165.0
# 3         Plymouth Satellite    18.0         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8        304.0      150.0
#
#    Weight Acceleration Model Origin
# 0  DOUBLE       DOUBLE   INT    CAT
# 1   3504.         12.0    70     US
# 2   3693.         11.5    70     US
# 3   3436.         11.0    70     US
# 4   3433.         12.0    70     US

# %%
df.loc[0]
# Out:
# Car             STRING
# MPG             DOUBLE
# Cylinders          INT
# Displacement    DOUBLE
# Horsepower      DOUBLE
# Weight          DOUBLE
# Acceleration    DOUBLE
# Model              INT
# Origin             CAT
# Name: 0, dtype: object

# %%
df.drop([0], inplace=True)

# %%
df
# Out:
#                            Car   MPG Cylinders Displacement Horsepower Weight  \
# 1    Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# 2            Buick Skylark 320  15.0         8        350.0      165.0  3693.
# 3           Plymouth Satellite  18.0         8        318.0      150.0  3436.
# 4                AMC Rebel SST  16.0         8        304.0      150.0  3433.
# 5                  Ford Torino  17.0         8        302.0      140.0  3449.
# ..                         ...   ...       ...          ...        ...    ...
# 402            Ford Mustang GL  27.0         4        140.0      86.00  2790.
# 403          Volkswagen Pickup  44.0         4        97.00      52.00  2130.
# 404              Dodge Rampage  32.0         4        135.0      84.00  2295.
# 405                Ford Ranger  28.0         4        120.0      79.00  2625.
# 406                 Chevy S-10  31.0         4        119.0      82.00  2720.
#
#     Acceleration Model  Origin
# ...

# %%
df.loc[400]
# Out:
# Car             Dodge Charger 2.2
# MPG                          36.0
# Cylinders                       4
# Displacement                135.0
# Horsepower                  84.00
# Weight                      2370.
# Acceleration                 13.0
# Model                          82
# Origin                         US
# Name: 400, dtype: object

# %%
df.iloc[[0, 1, -1]]
# Out:
#                            Car   MPG Cylinders Displacement Horsepower Weight  \
# 1    Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# 2            Buick Skylark 320  15.0         8        350.0      165.0  3693.
# 406                 Chevy S-10  31.0         4        119.0      82.00  2720.
#
#     Acceleration Model Origin
# 1           12.0    70     US
# 2           11.5    70     US
# 406         19.4    82     US

# %%
df.iloc[0:3, [0,3]]
# Out:
#                          Car Displacement
# 1  Chevrolet Chevelle Malibu        307.0
# 2          Buick Skylark 320        350.0
# 3         Plymouth Satellite        318.0

# %%
df.iloc[0:3, 1:5]
# Out:
#     MPG Cylinders Displacement Horsepower
# 1  18.0         8        307.0      130.0
# 2  15.0         8        350.0      165.0
# 3  18.0         8        318.0      150.0

# %%
df
# Out:
#                            Car   MPG Cylinders Displacement Horsepower Weight  \
# 1    Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# 2            Buick Skylark 320  15.0         8        350.0      165.0  3693.
# 3           Plymouth Satellite  18.0         8        318.0      150.0  3436.
# 4                AMC Rebel SST  16.0         8        304.0      150.0  3433.
# 5                  Ford Torino  17.0         8        302.0      140.0  3449.
# ..                         ...   ...       ...          ...        ...    ...
# 402            Ford Mustang GL  27.0         4        140.0      86.00  2790.
# 403          Volkswagen Pickup  44.0         4        97.00      52.00  2130.
# 404              Dodge Rampage  32.0         4        135.0      84.00  2295.
# 405                Ford Ranger  28.0         4        120.0      79.00  2625.
# 406                 Chevy S-10  31.0         4        119.0      82.00  2720.
#
#     Acceleration Model  Origin
# ...

# %%
df.set_index('Car')
# Out:
#                             MPG Cylinders Displacement Horsepower Weight  \
# Car
# Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# Buick Skylark 320          15.0         8        350.0      165.0  3693.
# Plymouth Satellite         18.0         8        318.0      150.0  3436.
# AMC Rebel SST              16.0         8        304.0      150.0  3433.
# Ford Torino                17.0         8        302.0      140.0  3449.
# ...                         ...       ...          ...        ...    ...
# Ford Mustang GL            27.0         4        140.0      86.00  2790.
# Volkswagen Pickup          44.0         4        97.00      52.00  2130.
# Dodge Rampage              32.0         4        135.0      84.00  2295.
# Ford Ranger                28.0         4        120.0      79.00  2625.
# Chevy S-10                 31.0         4        119.0      82.00  2720.
#
#                           Acceleration Model  Origin
# Car
# ...

# %%
df
# Out:
#                            Car   MPG Cylinders Displacement Horsepower Weight  \
# 1    Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# 2            Buick Skylark 320  15.0         8        350.0      165.0  3693.
# 3           Plymouth Satellite  18.0         8        318.0      150.0  3436.
# 4                AMC Rebel SST  16.0         8        304.0      150.0  3433.
# 5                  Ford Torino  17.0         8        302.0      140.0  3449.
# ..                         ...   ...       ...          ...        ...    ...
# 402            Ford Mustang GL  27.0         4        140.0      86.00  2790.
# 403          Volkswagen Pickup  44.0         4        97.00      52.00  2130.
# 404              Dodge Rampage  32.0         4        135.0      84.00  2295.
# 405                Ford Ranger  28.0         4        120.0      79.00  2625.
# 406                 Chevy S-10  31.0         4        119.0      82.00  2720.
#
#     Acceleration Model  Origin
# ...

# %%
type('MPG')
# Out:
# str

# %%
df['MPG'] = df['MPG'].astype(float)

# %%
print(df.dtypes)
# Out:
# Car              object
# MPG             float64
# Cylinders        object
# Displacement     object
# Horsepower       object
# Weight           object
# Acceleration     object
# Model            object
# Origin           object
# dtype: object

# %%
df['MPG'] = pd.to_numeric(df['MPG'])

# %%
df['MPG'] > 30
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 402    False
# 403     True
# 404     True
# 405    False
# 406     True
# Name: MPG, Length: 406, dtype: bool

# %%
print(type('MPG'))
# Out:
# <class 'str'>

# %%
df.loc[df['MPG'] > 30]
# Out:
#                      Car   MPG Cylinders Displacement Horsepower Weight  \
# 61   Toyota Corolla 1200  31.0         4        71.00      65.00  1773.
# 62           Datsun 1200  35.0         4        72.00      69.00  1613.
# 137          Datsun B210  31.0         4        79.00      67.00  1950.
# 139  Toyota Corolla 1200  32.0         4        71.00      65.00  1836.
# 152       Toyota Corolla  31.0         4        76.00      52.00  1649.
# ..                   ...   ...       ...          ...        ...    ...
# 399     Toyota Celica GT  32.0         4        144.0      96.00  2665.
# 400    Dodge Charger 2.2  36.0         4        135.0      84.00  2370.
# 403    Volkswagen Pickup  44.0         4        97.00      52.00  2130.
# 404        Dodge Rampage  32.0         4        135.0      84.00  2295.
# 406           Chevy S-10  31.0         4        119.0      82.00  2720.
#
#     Acceleration Model  Origin
# 61          19.0    71   Japan
# 62          18.0    71   Japan
# ...

# %%
df.loc[df['MPG'] > 40, ['MPG', 'Car']]
# Out:
#       MPG                              Car
# 252  43.1  Volkswagen Rabbit Custom Diesel
# 317  41.5                Volkswagen Rabbit
# 330  46.6                        Mazda GLC
# 332  40.8                       Datsun 210
# 333  44.3     Volkswagen Rabbit C (Diesel)
# 334  43.4       Volkswagen Dasher (diesel)
# 337  44.6              Honda Civic 1500 gl
# 338  40.9             Renault Lecar Deluxe
# 403  44.0                Volkswagen Pickup

# %%
df = df.set_index('Car')

# %%
df
# Out:
#                             MPG Cylinders Displacement Horsepower Weight  \
# Car
# Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# Buick Skylark 320          15.0         8        350.0      165.0  3693.
# Plymouth Satellite         18.0         8        318.0      150.0  3436.
# AMC Rebel SST              16.0         8        304.0      150.0  3433.
# Ford Torino                17.0         8        302.0      140.0  3449.
# ...                         ...       ...          ...        ...    ...
# Ford Mustang GL            27.0         4        140.0      86.00  2790.
# Volkswagen Pickup          44.0         4        97.00      52.00  2130.
# Dodge Rampage              32.0         4        135.0      84.00  2295.
# Ford Ranger                28.0         4        120.0      79.00  2625.
# Chevy S-10                 31.0         4        119.0      82.00  2720.
#
#                           Acceleration Model  Origin
# Car
# ...

# %%
df.drop('Ford Ranger')
# Out:
#                             MPG Cylinders Displacement Horsepower Weight  \
# Car
# Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# Buick Skylark 320          15.0         8        350.0      165.0  3693.
# Plymouth Satellite         18.0         8        318.0      150.0  3436.
# AMC Rebel SST              16.0         8        304.0      150.0  3433.
# Ford Torino                17.0         8        302.0      140.0  3449.
# ...                         ...       ...          ...        ...    ...
# Chevrolet Camaro           27.0         4        151.0      90.00  2950.
# Ford Mustang GL            27.0         4        140.0      86.00  2790.
# Volkswagen Pickup          44.0         4        97.00      52.00  2130.
# Dodge Rampage              32.0         4        135.0      84.00  2295.
# Chevy S-10                 31.0         4        119.0      82.00  2720.
#
#                           Acceleration Model  Origin
# Car
# ...

# %%
df.drop(['Ford Torino', 'Ford Ranger'])
# Out:
#                             MPG Cylinders Displacement Horsepower Weight  \
# Car
# Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# Buick Skylark 320          15.0         8        350.0      165.0  3693.
# Plymouth Satellite         18.0         8        318.0      150.0  3436.
# AMC Rebel SST              16.0         8        304.0      150.0  3433.
# Ford Galaxie 500           15.0         8        429.0      198.0  4341.
# ...                         ...       ...          ...        ...    ...
# Chevrolet Camaro           27.0         4        151.0      90.00  2950.
# Ford Mustang GL            27.0         4        140.0      86.00  2790.
# Volkswagen Pickup          44.0         4        97.00      52.00  2130.
# Dodge Rampage              32.0         4        135.0      84.00  2295.
# Chevy S-10                 31.0         4        119.0      82.00  2720.
#
#                           Acceleration Model  Origin
# Car
# ...

# %%
df.drop(columns = ['Weight', 'Model'])
# Out:
#                             MPG Cylinders Displacement Horsepower  \
# Car
# Chevrolet Chevelle Malibu  18.0         8        307.0      130.0
# Buick Skylark 320          15.0         8        350.0      165.0
# Plymouth Satellite         18.0         8        318.0      150.0
# AMC Rebel SST              16.0         8        304.0      150.0
# Ford Torino                17.0         8        302.0      140.0
# ...                         ...       ...          ...        ...
# Ford Mustang GL            27.0         4        140.0      86.00
# Volkswagen Pickup          44.0         4        97.00      52.00
# Dodge Rampage              32.0         4        135.0      84.00
# Ford Ranger                28.0         4        120.0      79.00
# Chevy S-10                 31.0         4        119.0      82.00
#
#                           Acceleration  Origin
# Car
# Chevrolet Chevelle Malibu         12.0      US
# Buick Skylark 320                 11.5      US
# ...

# %%
df.drop(['Weight', 'Model'], axis=1)
# Out:
#                             MPG Cylinders Displacement Horsepower  \
# Car
# Chevrolet Chevelle Malibu  18.0         8        307.0      130.0
# Buick Skylark 320          15.0         8        350.0      165.0
# Plymouth Satellite         18.0         8        318.0      150.0
# AMC Rebel SST              16.0         8        304.0      150.0
# Ford Torino                17.0         8        302.0      140.0
# ...                         ...       ...          ...        ...
# Ford Mustang GL            27.0         4        140.0      86.00
# Volkswagen Pickup          44.0         4        97.00      52.00
# Dodge Rampage              32.0         4        135.0      84.00
# Ford Ranger                28.0         4        120.0      79.00
# Chevy S-10                 31.0         4        119.0      82.00
#
#                           Acceleration  Origin
# Car
# Chevrolet Chevelle Malibu         12.0      US
# Buick Skylark 320                 11.5      US
# ...

# %%
df['Horsepower'] = df['Horsepower'].astype(float)

# %%
df['Displacement'] = df['Displacement'].astype(float)

# %%
df[['Horsepower', 'Displacement']] / 100
# Out:
#                            Horsepower  Displacement
# Car
# Chevrolet Chevelle Malibu        1.30          3.07
# Buick Skylark 320                1.65          3.50
# Plymouth Satellite               1.50          3.18
# AMC Rebel SST                    1.50          3.04
# Ford Torino                      1.40          3.02
# ...                               ...           ...
# Ford Mustang GL                  0.86          1.40
# Volkswagen Pickup                0.52          0.97
# Dodge Rampage                    0.84          1.35
# Ford Ranger                      0.79          1.20
# Chevy S-10                       0.82          1.19
#
# [406 rows x 2 columns]

# %%
crisis = pd.DataFrame([200000, 0.03], index=['Horsepower', 'Displacement'])
crisis.dtypes
# Out:
# 0    float64
# dtype: object

# %%
df[['Horsepower', 'Displacement']]
# Out:
#                            Horsepower  Displacement
# Car
# Chevrolet Chevelle Malibu       130.0         307.0
# Buick Skylark 320               165.0         350.0
# Plymouth Satellite              150.0         318.0
# AMC Rebel SST                   150.0         304.0
# Ford Torino                     140.0         302.0
# ...                               ...           ...
# Ford Mustang GL                  86.0         140.0
# Volkswagen Pickup                52.0          97.0
# Dodge Rampage                    84.0         135.0
# Ford Ranger                      79.0         120.0
# Chevy S-10                       82.0         119.0
#
# [406 rows x 2 columns]

# %%
df['Car'] = 'Chevy S-10'
df
# Out:
#                             MPG Cylinders  Displacement  Horsepower Weight  \
# Car
# Chevrolet Chevelle Malibu  18.0         8         307.0       130.0  3504.
# Buick Skylark 320          15.0         8         350.0       165.0  3693.
# Plymouth Satellite         18.0         8         318.0       150.0  3436.
# AMC Rebel SST              16.0         8         304.0       150.0  3433.
# Ford Torino                17.0         8         302.0       140.0  3449.
# ...                         ...       ...           ...         ...    ...
# Ford Mustang GL            27.0         4         140.0        86.0  2790.
# Volkswagen Pickup          44.0         4          97.0        52.0  2130.
# Dodge Rampage              32.0         4         135.0        84.0  2295.
# Ford Ranger                28.0         4         120.0        79.0  2625.
# Chevy S-10                 31.0         4         119.0        82.0  2720.
#
# ...

# %%
df.value_counts('Origin')
# Out:
# Origin
# US        254
# Japan      79
# Europe     73
# dtype: int64

# %%
df.rename(columns={
    'MPG':'Miles Per Gallon',
    'Cylinders' : 'Clndr'},
    index = {
        'Ford Torino': 'Ford_Torino',
        'Ford Ranger': 'Ford_Ranger'
    })
# Out:
#                            Miles Per Gallon Clndr  Displacement  Horsepower  \
# Car
# Chevrolet Chevelle Malibu              18.0     8         307.0       130.0
# Buick Skylark 320                      15.0     8         350.0       165.0
# Plymouth Satellite                     18.0     8         318.0       150.0
# AMC Rebel SST                          16.0     8         304.0       150.0
# Ford_Torino                            17.0     8         302.0       140.0
# ...                                     ...   ...           ...         ...
# Ford Mustang GL                        27.0     4         140.0        86.0
# Volkswagen Pickup                      44.0     4          97.0        52.0
# Dodge Rampage                          32.0     4         135.0        84.0
# Ford_Ranger                            28.0     4         120.0        79.0
# Chevy S-10                             31.0     4         119.0        82.0
#
# ...

# %%
df
# Out:
#                             MPG Cylinders  Displacement  Horsepower Weight  \
# Car
# Chevrolet Chevelle Malibu  18.0         8         307.0       130.0  3504.
# Buick Skylark 320          15.0         8         350.0       165.0  3693.
# Plymouth Satellite         18.0         8         318.0       150.0  3436.
# AMC Rebel SST              16.0         8         304.0       150.0  3433.
# Ford Torino                17.0         8         302.0       140.0  3449.
# ...                         ...       ...           ...         ...    ...
# Ford Mustang GL            27.0         4         140.0        86.0  2790.
# Volkswagen Pickup          44.0         4          97.0        52.0  2130.
# Dodge Rampage              32.0         4         135.0        84.0  2295.
# Ford Ranger                28.0         4         120.0        79.0  2625.
# Chevy S-10                 31.0         4         119.0        82.0  2720.
#
# ...

# %%
df.rename(index=str.upper)
# Out:
#                             MPG Cylinders  Displacement  Horsepower Weight  \
# Car
# CHEVROLET CHEVELLE MALIBU  18.0         8         307.0       130.0  3504.
# BUICK SKYLARK 320          15.0         8         350.0       165.0  3693.
# PLYMOUTH SATELLITE         18.0         8         318.0       150.0  3436.
# AMC REBEL SST              16.0         8         304.0       150.0  3433.
# FORD TORINO                17.0         8         302.0       140.0  3449.
# ...                         ...       ...           ...         ...    ...
# FORD MUSTANG GL            27.0         4         140.0        86.0  2790.
# VOLKSWAGEN PICKUP          44.0         4          97.0        52.0  2130.
# DODGE RAMPAGE              32.0         4         135.0        84.0  2295.
# FORD RANGER                28.0         4         120.0        79.0  2625.
# CHEVY S-10                 31.0         4         119.0        82.0  2720.
#
# ...

# %%
df.rename(index = lambda x: x.lower())
# Out:
#                             MPG Cylinders  Displacement  Horsepower Weight  \
# Car
# chevrolet chevelle malibu  18.0         8         307.0       130.0  3504.
# buick skylark 320          15.0         8         350.0       165.0  3693.
# plymouth satellite         18.0         8         318.0       150.0  3436.
# amc rebel sst              16.0         8         304.0       150.0  3433.
# ford torino                17.0         8         302.0       140.0  3449.
# ...                         ...       ...           ...         ...    ...
# ford mustang gl            27.0         4         140.0        86.0  2790.
# volkswagen pickup          44.0         4          97.0        52.0  2130.
# dodge rampage              32.0         4         135.0        84.0  2295.
# ford ranger                28.0         4         120.0        79.0  2625.
# chevy s-10                 31.0         4         119.0        82.0  2720.
#
# ...

# %%
df
# Out:
#                             MPG Cylinders  Displacement  Horsepower Weight  \
# Car
# Chevrolet Chevelle Malibu  18.0         8         307.0       130.0  3504.
# Buick Skylark 320          15.0         8         350.0       165.0  3693.
# Plymouth Satellite         18.0         8         318.0       150.0  3436.
# AMC Rebel SST              16.0         8         304.0       150.0  3433.
# Ford Torino                17.0         8         302.0       140.0  3449.
# ...                         ...       ...           ...         ...    ...
# Ford Mustang GL            27.0         4         140.0        86.0  2790.
# Volkswagen Pickup          44.0         4          97.0        52.0  2130.
# Dodge Rampage              32.0         4         135.0        84.0  2295.
# Ford Ranger                28.0         4         120.0        79.0  2625.
# Chevy S-10                 31.0         4         119.0        82.0  2720.
#
# ...

# %%
df= df.append(pd.Series(
    {'Cylinders': 10,
     'Model' : 22},
     name='Togg'
))

# %%
df
# Out:
#                             MPG Cylinders  Displacement  Horsepower Weight  \
# Car
# Chevrolet Chevelle Malibu  18.0         8         307.0       130.0  3504.
# Buick Skylark 320          15.0         8         350.0       165.0  3693.
# Plymouth Satellite         18.0         8         318.0       150.0  3436.
# AMC Rebel SST              16.0         8         304.0       150.0  3433.
# Ford Torino                17.0         8         302.0       140.0  3449.
# ...                         ...       ...           ...         ...    ...
# Volkswagen Pickup          44.0         4          97.0        52.0  2130.
# Dodge Rampage              32.0         4         135.0        84.0  2295.
# Ford Ranger                28.0         4         120.0        79.0  2625.
# Chevy S-10                 31.0         4         119.0        82.0  2720.
# Togg                        NaN      10.0           NaN         NaN    NaN
#
# ...

# %%
df.loc['Togg'] = pd.Series({'Horsepower': 150, 'Origin': 'TR'})

# %%
df
# Out:
#                             MPG Cylinders  Displacement  Horsepower Weight  \
# Car
# Chevrolet Chevelle Malibu  18.0         8         307.0       130.0  3504.
# Buick Skylark 320          15.0         8         350.0       165.0  3693.
# Plymouth Satellite         18.0         8         318.0       150.0  3436.
# AMC Rebel SST              16.0         8         304.0       150.0  3433.
# Ford Torino                17.0         8         302.0       140.0  3449.
# ...                         ...       ...           ...         ...    ...
# Volkswagen Pickup          44.0         4          97.0        52.0  2130.
# Dodge Rampage              32.0         4         135.0        84.0  2295.
# Ford Ranger                28.0         4         120.0        79.0  2625.
# Chevy S-10                 31.0         4         119.0        82.0  2720.
# Togg                        NaN       NaN           NaN       150.0    NaN
#
# ...

# %%
df.reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-20da24c655af> in <module>
# ----> 1 df.reset_index()
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5797                     )
#    5798
# -> 5799                 new_obj.insert(0, name, level_values)
#    5800
#    5801         new_obj.index = new_index
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
# ...

# %%
df.set_index('Origin')
# Out:
#          MPG Cylinders  Displacement  Horsepower Weight Acceleration Model  \
# Origin
# US      18.0         8         307.0       130.0  3504.         12.0    70
# US      15.0         8         350.0       165.0  3693.         11.5    70
# US      18.0         8         318.0       150.0  3436.         11.0    70
# US      16.0         8         304.0       150.0  3433.         12.0    70
# US      17.0         8         302.0       140.0  3449.         10.5    70
# ...      ...       ...           ...         ...    ...          ...   ...
# Europe  44.0         4          97.0        52.0  2130.         24.6    82
# US      32.0         4         135.0        84.0  2295.         11.6    82
# US      28.0         4         120.0        79.0  2625.         18.6    82
# US      31.0         4         119.0        82.0  2720.         19.4    82
# TR       NaN       NaN           NaN       150.0    NaN          NaN   NaN
#
#                Car
# Origin
# US      Chevy S-10
# ...

# %% [markdown]
# Creating columns from other columns

# %%
df[['Origin', 'Horsepower']]
# Out:
#                            Origin  Horsepower
# Car
# Chevrolet Chevelle Malibu      US       130.0
# Buick Skylark 320              US       165.0
# Plymouth Satellite             US       150.0
# AMC Rebel SST                  US       150.0
# Ford Torino                    US       140.0
# ...                           ...         ...
# Volkswagen Pickup          Europe        52.0
# Dodge Rampage                  US        84.0
# Ford Ranger                    US        79.0
# Chevy S-10                     US        82.0
# Togg                           TR       150.0
#
# [407 rows x 2 columns]

# %% [markdown]
# Statistical Information

# %%
df.head()
# Out:
#                             MPG Cylinders  Displacement  Horsepower Weight  \
# Car
# Chevrolet Chevelle Malibu  18.0         8         307.0       130.0  3504.
# Buick Skylark 320          15.0         8         350.0       165.0  3693.
# Plymouth Satellite         18.0         8         318.0       150.0  3436.
# AMC Rebel SST              16.0         8         304.0       150.0  3433.
# Ford Torino                17.0         8         302.0       140.0  3449.
#
#                           Acceleration Model Origin         Car
# Car
# Chevrolet Chevelle Malibu         12.0    70     US  Chevy S-10
# Buick Skylark 320                 11.5    70     US  Chevy S-10
# Plymouth Satellite                11.0    70     US  Chevy S-10
# AMC Rebel SST                     12.0    70     US  Chevy S-10
# Ford Torino                       10.5    70     US  Chevy S-10

# %%
df.describe()
# Out:
#               MPG  Displacement  Horsepower
# count  406.000000    406.000000  407.000000
# mean    23.051232    194.779557  103.643735
# std      8.401777    104.922458   40.536225
# min      0.000000     68.000000    0.000000
# 25%     17.000000    105.000000   75.000000
# 50%     22.350000    151.000000   94.000000
# 75%     29.000000    302.000000  129.500000
# max     46.600000    455.000000  230.000000

# %%
horse_power = df['Horsepower']

# %%
horse_power.min(), horse_power.max()
# Out:
# (0.0, 230.0)

# %%
len(horse_power)
# Out:
# 407

# %%
horse_power.mean()
# Out:
# 103.64373464373465

# %%
horse_power.std()
# Out:
# 40.536225407091564

# %%
horse_power.median()
# Out:
# 94.0

# %%
horse_power.describe()
# Out:
# count    407.000000
# mean     103.643735
# std       40.536225
# min        0.000000
# 25%       75.000000
# 50%       94.000000
# 75%      129.500000
# max      230.000000
# Name: Horsepower, dtype: float64

# %%
horse_power.quantile(.25)
# Out:
# 75.0

# %%
horse_power.quantile([.2, .4, .6, .8, 1])
# Out:
# 0.2     71.0
# 0.4     88.0
# 0.6    100.0
# 0.8    141.6
# 1.0    230.0
# Name: Horsepower, dtype: float64
